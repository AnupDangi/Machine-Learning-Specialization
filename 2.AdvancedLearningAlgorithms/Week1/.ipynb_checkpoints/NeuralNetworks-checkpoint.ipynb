# %% [markdown]
# ## This week, you'll explore neural networks and their use in classification tasks. You'll use TensorFlow to easily build a neural network and later code one from scratch in Python. Key topics include neural network diagrams, layers, feature learning, activations, and image classification. Optionally, you can learn about vectorization for faster computations.

# %% [markdown]
# Neural Networks:
# - Origin: Algorithms that try to mimic the brain.
# - Used : in the 1980's and early 1990's .
# - Fell out of favor in the late 1990's.
# - Resurgence from around 2005.
# - Speech Recognition->then image recognition->then text(NLP)
#
# <img src="images/HistoryNN.png" width="600"/>

# %% [markdown]
# **1. Inspiration behind Neural Network is Biological Neuron which was a thought given to build a software that mimic human brain**
#
# <img src="images/neuron.png" width="600"/>
#
# **2.Why Neural Networks are on demand now only why not before?**
#
# <img src="images/WhyNow.png" align="left" width="600"/>

# %% [markdown]
# ## Demand Prediction
# **Question :Will this product be a top seller or not?**
#
# **1. Simple Example**
#
# <img src="images/Demandpred.png"  width="600"/>
#
# **2. Real World Example**
#
# <img src="images/Demandpredeg.png" width="600"/>
#
# **3.Another Question how will any neuron will pick the right input feature for processing?**
# - The answer is that every neuron has access to all the input features and the relationship in pictorial form looks like this given below
#
#   <img src="images/selectfeature.png" align="left" width="600"/>
#
# **4.Multiple Hidden Layer**
#
# <img src="images/mulhiddenlayer.png"  width="600"/>

# %% [markdown]
# ## Computer Vision Neural Networks
# - Image Recognition:
#
#   **What is Image?**
#   - It is stored in the form of pixels ie rows and columns for eg for 2d image there are number of rows pixel and column pixels. The image is stored in the form of matrix and to pass the input features to neural network it is converted into 1d input array as given below. so the number of rows becomes 1000*1000 pixels ie 1million input parameters are requrired to detect image of 1000px by 100px.
#   <img src="images/imagepixels.png" width="600"/>
#
# **Here is a Neural Network architecture for face recognition**
#
#   <img src="images/FacerecogNN.png" width="600"/>
#
#   - We can also observe that each neuron layer passes the output to the other layer so the output for layers are trying to predict
#   - first lines and grids for the first layer then
#   - the second layer is trying to predict the different body parts and
#   -  third layer is trying to predict the faces based on previous neurons input.
#   - Then finally passes the output layer and make prediction
#
# **Similarly Car Classification can also be done**
#
#   <img src="images/carclassification.png" width="600"/>

# %% [markdown]
# ## Neural Network Layer Full Explanation in pictorial form with formulation and calculation for multi layer NN
# - Each Layer working Mechanism how activation for neuron is calculation using logistic regression. and how it is fed into another layer as input.
#   <img src="images/NNArch.png" width="600"/>
#
# - Layer2 Representation Mathematical Form
#
# <img src="images/Layer2NN.png" width="600"/>
#
# - Make inferences and predict based on last layer's output
#
#   <img src="images/PredictOutputNN.png" width="600"/>

# %% [markdown]
# ## More Complex Neural Networks layers
#
# <img src="images/CompNN.png" width="600"/>
#
# **Here is the example of generalized Notation**
#
# <img src="images/generalizedNotation.png" width="600"/>

# %% [markdown]
# ** Here is an example of Inference Making or Prediction using Forward Propagation
# - This is an example of Handwriting Digit Recognition
#
# <img src="images/HDRNN.png" width="600"/>
#
# - Forward Propagation using sigmoid function
#
#   <img src="images/HDRForwardProg.png" width="600"/>

# %% [markdown]
# **Packages**
#
# Tensorflow and Keras
# Tensorflow is a machine learning package developed by Google. In 2019, Google integrated Keras into Tensorflow and released Tensorflow 2.0. Keras is a framework developed independently by François Chollet that creates a simple, layer-centric interface to Tensorflow. This course will be using the Keras interface.

# %% [markdown]
# **TensorFlow Implementation:**
#    - TensorFlow: A leading framework for implementing deep learning algorithms.
# - Neural Networks: Same algorithms can be applied to various applications.
#   -  Example: Coffee roasting optimization using temperature and duration as input features.
#     - Layers:
#     - Layer 1: First hidden layer with multiple units.
#      - Layer 2: Second hidden layer with a single unit.
#     - Forward Propagation:
#     - Compute activations (a1, a2) through layers.
#     - Use sigmoid activation function.
#     - Thresholding: Determine output (y-hat) based on activation values.
#     - Real-World Application: Machine learning can optimize coffee roasting processes
#
# **1.Coffee Roasting Implementation**
#
# <img src="images/CoffeeRoasting.png" width="600"/>
#
#
# **2.Building the tensorflow model**
#
# <img src="images/buildtf.png"  width="600"/>
#
# **3.Model for digit classification**
#
# <img src="images/digitclassification.png"  width="600"/>

# %% [markdown]
# **1.Data Representation in Numpy Arrays**
#
# <img src="images/numpyarrays.png" align="600" width="600"/>
#
# **2.Representation in code and what is the difference**
#
# <img src="images/nparrayrep.png" align="600" width="600"/>
#
# **3.Activation Vector using tensorflow model**
#
# <img src="images/activationvector.png" align="600" width="600"/>
#
# **Summary: Tensorflow reads the numpy array data into tensor and then read to process the data and the output can be converted back into numpy or can be kept in tensorflow as well.**

# %% [markdown]
# **Building a neural network architecture**
#
# <img src="images/NN1.png"  width="600"/>
#
# **1.Building Neural Network Architecture**
#
# <img src="images/BuildingNN.png"  width="600"/>
#
# **2.Automation of manual task using Sequential library to combine all the layers to make a Neural Network**
# <img src="images/Sequentialmodel.png"  width="600"/>
#
# **3.Digit Classification Neural Network**
#
# <img src="images/DigitClassificationNN.png"  width="600"/>

# %% [markdown]
# **Forward Propagation Using Numpy Implementation Code**
#
# <img src="images/forwardpropagationUsingNumpy.png" width="600"/>
#
# **Creating a Dense Layer**
#
# <img src="images/forwardprog.png" width="600"/>

# %% [markdown]
# **AGI(Artificial General Intelligence**
#
# <img src="images/AGI.png" width="600"/>
#
# **Can we mimic the human brain?**
#
# <img src="images/brainandNN.png" width="600"/>
#
# **The one learning Algorithm hypothesis**
#
# **Ear sensor learns to see**
#
# <img src="images/auditory.png" width="600"/>
#
# **Touch sensor learns to see**
#
# <img src="images/sense.png" width="600"/>
#
# **Representation of different sensors in brain**
#
# <img src="images/sensorrepinbrain.png" width="600"/>

# %% [markdown]
# **Vectorization**
#
# **Neural Network can made by calculating matrix multiplication**
#
# <img src="images/loopvsvectorization.png" width="600"/>
#
# <img src="images/dotproducts.png" width="600"/>
#
# <img src="images/vecmacmul.png" width="600"/>
#
# <img src="images/loopvsvectorization.png" width="600"/>
#
# <img src="images/macmacmul.png" width="600"/>
#
# <img src="images/matmulrules.png" width="600"/>
#
# <img src="images/matmulrules1.png" width="600"/>

# %% [markdown]
# **Matrix multiplication code**
